# %% [markdown]
# # Customer Retention

# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_excel('customer_retention_dataset.xlsx',sheet_name='codedsheet')

# %%
# displays top 5 rows

df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
# checking the data dimension

df.shape
# Out:
# (269, 71)

# %% [markdown]
# There are 269 rows and 71 columns

# %%
# prints information of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %%
col_list = ['Gender','Age','City','Pin Code','How Long Shopping','no_of_timespurchase',
            'Internet access','device used','Screen size','OS type','browser type','channel_first','reaching type_after',
            'time spent','payment type','frequency of abandoning shopping cart','reason for abandoning cart',
            'easy content','product info importance','info on seller and product','clear relevant info','ease of navigation',
            'speed','interface','Convenient Payment methods','trust','empathy','privacy','communication','benefits',
            'enjoyment','convinient and flexible','return and replacemnt policy','loyolty program','quality of info',
            'website/app quality','net benefit',
        'User satisfaction cannot exist without trust','variety','complete and relevant product info','Monetary savings',
            'patronizing retailer','sense of adventure','social status','gratification','fulfill certain roles',
            'value for money','online retailers','Easy to use website or application','Visual appealing web-page layout',
            'Wild variety of product on offer','Complete_relevant_description_Prodinformation',
            'Fast loading website speed of website and application','Reliability of the website or application',
            'Quickness to complete purchase','Availability of several payment options','Speedy order delivery',
             'Privacy of customers information','Security of customer financial information','Perceived Trustworthiness',
            'online assistance','Longer time to get logged in (promotion, sales period)',
            'Longer time in displaying graphics and photos (promotion, sales period)',
            'Late declaration of price (promotion, sales period)','Longer page loading time (promotion, sales period)',
            'Limited mode of payment (promotion, sales period)','Longer delivery period','Change in website/Application design',
            'Frequent disruption when moving from one page to another','Website is as efficient as before',
            'Indian online retailer you would recommend to a friend'
        ]

# %%
df.columns= col_list

# %%
df.head()
# Out:
#    Gender  Age           City  Pin Code  How Long Shopping  \
# 0       0    3          Delhi    110009                  5
# 1       1    2          Delhi    110030                  5
# 2       1    2  Greater Noida    201308                  4
# 3       0    2        Karnal     132001                  4
# 4       1    2     Bangalore     530068                  3
#
#    no_of_timespurchase  Internet access  device used  Screen size  OS type  \
# 0                    4                4            3            5        1
# 1                    5                2            1            2        3
# 2                    5                3            1            4        2
# 3                    1                3            1            4        3
# 4                    2                2            1            2        3
#
#    ...  Longer time to get logged in (promotion, sales period)  \
# 0  ...                                          Amazon.in
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df.dtypes
# Out:
# Gender                                                                      int64
# Age                                                                         int64
# City                                                                       object
# Pin Code                                                                    int64
# How Long Shopping                                                           int64
# no_of_timespurchase                                                         int64
# Internet access                                                             int64
# device used                                                                 int64
# Screen size                                                                 int64
# OS type                                                                     int64
# browser type                                                                int64
# ...

# %%
df.isnull().sum()
# Out:
# Gender                                                                     0
# Age                                                                        0
# City                                                                       0
# Pin Code                                                                   0
# How Long Shopping                                                          0
# no_of_timespurchase                                                        0
# Internet access                                                            0
# device used                                                                0
# Screen size                                                                0
# OS type                                                                    0
# browser type                                                               0
# channel_first                                                              0
# ...

# %%
df['online retailers'].unique()
# Out:
# array(['Amazon.in, Paytm.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com, Paytm.com'], dtype=object)

# %%
# Statistical Summary

df.describe().T
# Out:
#                                               count           mean  \
# Gender                                        269.0       0.669145
# Age                                           269.0       2.959108
# Pin Code                                      269.0  220465.747212
# How Long Shopping                             269.0       3.524164
# no_of_timespurchase                           269.0       2.672862
# Internet access                               269.0       3.260223
# device used                                   269.0       1.676580
# Screen size                                   269.0       4.282528
# OS type                                       269.0       1.776952
# browser type                                  269.0       1.275093
# channel_first                                 269.0       1.360595
# reaching type_after                           269.0       2.546468
# time spent                                    269.0       3.921933
# ...

# %%
df.describe(include=['O']).T
# Out:
#                                                    count unique  \
# City                                                 269     11
# online retailers                                     269      9
# Easy to use website or application                   269     10
# Visual appealing web-page layout                     269     10
# Wild variety of product on offer                     269      9
# Complete_relevant_description_Prodinformation        269     11
# Fast loading website speed of website and appli...   269     10
# Reliability of the website or application            269     10
# Quickness to complete purchase                       269      9
# Availability of several payment options              269     11
# Speedy order delivery                                269      6
# Privacy of customers information                     269     11
# Security of customer financial information           269     11
# Perceived Trustworthiness                            269      9
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %% [markdown]
# There are no null values in the dataset

# %%
# checking correlation

df.corr()
# Out:
#                                                 Gender       Age  Pin Code  \
# Gender                                        1.000000 -0.034449  0.260696
# Age                                          -0.034449  1.000000 -0.057393
# Pin Code                                      0.260696 -0.057393  1.000000
# How Long Shopping                            -0.046005  0.014049  0.092980
# no_of_timespurchase                           0.076121  0.005089 -0.021229
# Internet access                              -0.200974  0.024228  0.134879
# device used                                  -0.241847  0.292176 -0.103424
# Screen size                                  -0.058760  0.227841 -0.189814
# OS type                                      -0.038207 -0.133597  0.077905
# browser type                                 -0.116712 -0.151708  0.063588
# channel_first                                -0.166694 -0.046915  0.082911
# ...

# %%
# plotting heatmap

corr_mat = df.corr()
plt.figure(figsize=[80,80])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.savefig("Correlation_matrix.jpg")
plt.show()

# %%
# Let's check the data distribution among all the columns

df.plot(kind='density',subplots=True,layout=(6,11), sharex=False, legend=False,fontsize=1,figsize=(18,12))
plt.show()
